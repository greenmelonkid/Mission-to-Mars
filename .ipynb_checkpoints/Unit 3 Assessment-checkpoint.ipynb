# %%
import pandas as pd

# %%
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
engine = create_engine(f"postgresql://postgres:postgres@localhost:5432/cta_db")
l_stations_df.to_sql(name='stations', con=engine, index=False)
ridership_df.to_sql(name='ridership', con=engine, index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2275         try:
# -> 2276             return fn()
#    2277         except dialect.dbapi.Error as e:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     772         if not fairy:
# --> 773             fairy = _ConnectionRecord.checkout(pool)
#     774
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
# ...

# %%
list_of_stops = pd.read_csv("C:\\Users\\lag86\\OneDrive\\Desktop\\BOOTCAMP STUFF\\Unit Assessments\\Unit 3 - Databases\\CTA_list_of_L_stops.csv")
ridership = pd.read_csv("C:\\Users\\lag86\\OneDrive\\Desktop\\BOOTCAMP STUFF\\Unit Assessments\\Unit 3 - Databases\\CTA_ridership_daily_totals.csv")

# %%
list_of_stops.MAP.value_counts()
# Out:
# 40540    4
# 41320    4
# 41400    4
# 40080    4
# 41220    4
#         ..
# 40790    2
# 40280    2
# 41310    2
# 40800    2
# 40960    2
# Name: MAP_ID, Length: 143, dtype: int64

# %%
#l_stops_df = pd.read_csv("C:\\Users\\lag86\\OneDrive\\Desktop\\BOOTCAMP STUFF\\Unit Assessments\\Unit 3 - Databases\\CTA_list_of_L_stops.csv")
#station_bools = l_stops_df[['MAP_ID','ADA','RED','BLUE','G','BRN','P','Pexp','Y','Pnk','O']].groupby().any()
#l_stations_df = l_stops_df[['MAP_ID','STATION_NAME','STATION_DESCRIPTIVE_NAME','Location']].merge(station_bools, how='left', left_on='MAP_ID', right_index=True).drop_duplicates()

# %%
l_stops_df = pd.read_csv("C:\\Users\\lag86\\OneDrive\\Desktop\\BOOTCAMP STUFF\\Unit Assessments\\Unit 3 - Databases\\CTA_list_of_L_stops.csv")
station_bools = l_stops_df[['MAP_ID','ADA','RED','BLUE','G','BRN','P','Pexp','Y','Pnk','O']].groupby('MAP_ID').any()
l_stations_df = l_stops_df[['MAP_ID','STATION_NAME','STATION_DESCRIPTIVE_NAME','Location']] \
    .merge(station_bools, how='left', left_on='MAP_ID', right_index=True).drop_duplicates()

# %%
l_stations_df[['latitude','longitude']] = \
   l_stations_df['Location'].str.replace('\(|\)','',regex=True) \
   .str.split(',', expand=True).apply(pd.to_numeric)
l_stations_df.drop('Location', axis=1, inplace=True)

# %%
ridership_df = pd.read_csv("C:\\Users\\lag86\\OneDrive\\Desktop\\BOOTCAMP STUFF\\Unit Assessments\\Unit 3 - Databases\\CTA_ridership_daily_totals.csv")

# %%
df = pd.merge(ridership_df, l_stations_df, how='left', left_on='station_id', right_on='MAP_ID')
df[df['latitude'] < 41.881]['rides'].sum()
# Out:
# 275328019
